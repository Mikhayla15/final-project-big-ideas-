# %% [markdown]
# ## INTRODUCTION

# %% [markdown]
# My name is Aaron Amodu and for this project our goal was to identify the safest neighborhood in Pittsburgh to reside in. I conducted a process that relied on police and arrest data as the foundation for my metric. Im using this metric to provide a clear understanding of safety levels across neighborhoods. The alternative metric I considered was utilizing Facebook community complaints but then I realized the potential for this approach would give me broad results that wouldnt really correspond with deciding wether or not it was a safe neigborhood or not.

# %% [markdown]
# ## METRIC

# %% [markdown]
# My metric I used is pittsburgh police arrest data. I examined the frequency of reported crimes and the locations where the most arrests occurred. By analyzing this data, I was able to identify the neighborhoods with the lowest crime rates which provided insights into safety levels within each area. The dataset I used  consisted of records of police arrests , their information and the location of where it happened.

# %% [markdown]
# ## BEST NEIGBORHOOD

# %% [markdown]
# For this dataset it shows Pittsburgh Police Arrest Data and categorizes the inmates by city , gender , race and allows you to see the time they got arrested and where they got arrested. I will be using this data to pinpoint the location they got arrested to reveal what neigborhood has the most crime.

# %%
import pandas as pd

Dataset = pd.read_csv('Dataset.csv')

Dataset.head()
# Out:
#    _id       PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 0    1  1975272  16158872  42.0      F    B  2016-08-24T12:20:00
# 1    2  1974456  16144120  31.0      M    W  2016-08-03T14:55:00
# 2    3  1974466  16144165  63.0      F    B  2016-08-03T16:45:00
# 3    4  1974550  16145257  25.0      F    W  2016-08-05T02:36:00
# 4    5  1974596  16145962  25.0      M    B  2016-08-06T02:00:00
#
#                                      ARRESTLOCATION  \
# 0         4700 Block Centre AV Pittsburgh, PA 15213
# 1  4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2        900 Block Freeport RD Fox Chapel, PA 15238
# 3       Foreland ST & Cedar AV Pittsburgh, PA 15212
# 4         900 Block Woodlow ST Pittsburgh, PA 15205
#
#                                             OFFENSES  \
# 0                                 3929 Retail Theft.
# 1       13(a)(16) Possession of Controlled Substance
# 2                                 3929 Retail Theft.
# ...

# %% [markdown]
# This code looks at a dataset of arrests in Pittsburgh and focuses on where these arrests happens the least. I used Pandas to grab the data and Matplotlib for visualization and creating the bar graph.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

dataset = pd.read_csv('Dataset.csv')


neighborhood_counts = dataset['INCIDENTNEIGHBORHOOD'].value_counts().sort_values() 


top_5_least_arrests = neighborhood_counts.head(5)

plt.figure(figsize=(8, 6))

top_5_least_arrests.plot(kind='bar')
plt.title('Top 5 Locations with Least Amount of Arrests in Pittsburgh')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Arrests')
plt.xticks(rotation=45) # Rotating x-axis labels for better readability


plt.show()

# %% [markdown]
#      For this code first I imported the pandas library then it reads a CSV file named 'Dataset.csv' into a pandas DataFrame called arrests_data'. The next line prints out the first few rows of the DataFrame to show what the data looks like. After that, it groups the data by the incident neighborhoods, counts the number of arrests in each neighborhood, and sorts them in order based on the number of arrests. Finally, it prints out the neighborhood with the least number of arrests.

# %%
import pandas as pd


arrests_data = pd.read_csv('Dataset.csv')


print(arrests_data.head())



arrests_by_location = arrests_data.groupby(['INCIDENTNEIGHBORHOOD']).size().reset_index(name='Arrests')


sorted_locations = arrests_by_location.sort_values(by='Arrests')


best_location = sorted_locations.iloc[0]
print("The best location in Pittsburgh with the least arrests is:")
print(best_location['INCIDENTNEIGHBORHOOD'])

print("Number of arrests in this location:", best_location['Arrests'])
# Out:
#    _id       PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 0    1  1975272  16158872  42.0      F    B  2016-08-24T12:20:00
# 1    2  1974456  16144120  31.0      M    W  2016-08-03T14:55:00
# 2    3  1974466  16144165  63.0      F    B  2016-08-03T16:45:00
# 3    4  1974550  16145257  25.0      F    W  2016-08-05T02:36:00
# 4    5  1974596  16145962  25.0      M    B  2016-08-06T02:00:00
#
#                                      ARRESTLOCATION  \
# 0         4700 Block Centre AV Pittsburgh, PA 15213
# 1  4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2        900 Block Freeport RD Fox Chapel, PA 15238
# 3       Foreland ST & Cedar AV Pittsburgh, PA 15212
# 4         900 Block Woodlow ST Pittsburgh, PA 15205
#
#                                             OFFENSES  \
# 0                                 3929 Retail Theft.
# 1       13(a)(16) Possession of Controlled Substance
# 2                                 3929 Retail Theft.
# ...

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# When it comes to determining the "best neighborhood", relying on data can paint a different picture compared to personal experiences. When I started looking at the data using tools like pandas and matplotlib I was able to examining arrest records and create graphs that led me to realize that Mt. Oliver stands out as the safest neighborhood with the fewest arrests. Im not from pittsburgh so i didnt have a guess on what the safest neigborhood was beforehand but after analyzing the data im confident that Mt. Oliver is but compared to my favorite neigborhood back home I prefer Mt. Oliver.

# %% [markdown]
# # Introduction

# %% [markdown]
#  The final project for this class is to determine the best neighborhood in Pittsburgh. Since there are several different ways to determine the best neighborhood in Pittsburgh, our group decided to find the neighborhood with the least amount of  crime.Our metric uses police/jail reports, engagning in fighting , and crimes involving arson to detemine the negiborhood with the least crime. Some alternatives we explored were property value, quality of life, police presence and respose time.

# %% [markdown]
# # Metric

# %% [markdown]
#  My sub-metric is fire. I am measuring the neighborhood that has the most crimes relating to arson. I am using the Police Incident Blotter Archive to show this data.

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pandas as pd
dataset = pd.read_csv("data.csv")
dataset.head(10)
# Out:
#       _id       PK       CCR  HIERARCHY         INCIDENTTIME  \
# 0   54017  2135988   5232936          5  2005-11-24T23:00:00
# 1  274535  3265945  21186829          8  2021-10-11T20:47:00
# 2    3403  2809123  16019890         99  2016-02-02T12:58:00
# 3  191712  3111645  19203614          8  2019-10-06T14:51:00
# 4  342641  3403683  23087637          8  2023-06-09T18:58:00
# 5  239099  3197959  20228065          8  2020-12-11T03:26:00
# 6   36110  2871450  16208930         99  2016-11-05T16:32:00
# 7    1505  2802809  16009039          8  2016-01-15T17:30:00
# 8  155313  3046946  18245877          8  2018-12-15T01:01:00
# 9  263321  3245216  21124915          8  2021-07-12T22:00:00
#
#                                 INCIDENTLOCATION CLEAREDFLAG  \
# 0            0 Block TECUMSEH ST PITTSBURGH, PA            N
# 1         1000 Block 5th AV Pittsburgh, PA 15219           N
# 2         1000 Block 5th AV Pittsburgh, PA 15219           N
# ...

# %% [markdown]
# This line of code drops all the columns without the arson crimes.

# %%
dataset[dataset['OFFENSES'].notna()]
# Out:
#         _id       PK       CCR  HIERARCHY         INCIDENTTIME  \
# 0     54017  2135988   5232936          5  2005-11-24T23:00:00
# 1    274535  3265945  21186829          8  2021-10-11T20:47:00
# 2      3403  2809123  16019890         99  2016-02-02T12:58:00
# 3    191712  3111645  19203614          8  2019-10-06T14:51:00
# 4    342641  3403683  23087637          8  2023-06-09T18:58:00
# ..      ...      ...       ...        ...                  ...
# 549  143343  3022691  18166605          8  2018-08-27T22:23:00
# 550  149761  3034967  18213261         99  2018-10-27T16:43:00
# 551   43711  2110356   5131581         99  2005-07-13T18:45:00
# 552   99904  2113351   5131581         99  2005-07-13T18:45:00
# 553  212368  3149056  20062432          8  2020-03-31T17:12:00
#
#                                     INCIDENTLOCATION CLEAREDFLAG  \
# 0                0 Block TECUMSEH ST PITTSBURGH, PA            N
# 1             1000 Block 5th AV Pittsburgh, PA 15219           N
# ...

# %% [markdown]
# This line of code filters through the dataset to show only the arson related crimes

# %%
arson_data = dataset[dataset['OFFENSES'].str.contains('ARSON', case=False, na=False)]
print(arson_data)
# Out:
#         _id       PK       CCR  HIERARCHY         INCIDENTTIME  \
# 0     54017  2135988   5232936          5  2005-11-24T23:00:00
# 1    274535  3265945  21186829          8  2021-10-11T20:47:00
# 2      3403  2809123  16019890         99  2016-02-02T12:58:00
# 3    191712  3111645  19203614          8  2019-10-06T14:51:00
# 5    239099  3197959  20228065          8  2020-12-11T03:26:00
# ..      ...      ...       ...        ...                  ...
# 548  345493  3409725  23102841          8  2023-07-05T14:44:00
# 549  143343  3022691  18166605          8  2018-08-27T22:23:00
# 550  149761  3034967  18213261         99  2018-10-27T16:43:00
# 551   43711  2110356   5131581         99  2005-07-13T18:45:00
# 552   99904  2113351   5131581         99  2005-07-13T18:45:00
#
#                                     INCIDENTLOCATION CLEAREDFLAG  \
# 0                0 Block TECUMSEH ST PITTSBURGH, PA            N
# 1             1000 Block 5th AV Pittsburgh, PA 15219           N
# ...

# %% [markdown]
# This code removes the rows that have missing values.

# %%
arson_data_filtered = arson_data[dataset['INCIDENTNEIGHBORHOOD'].notna()]
print(arson_data_filtered)
# Out:
#         _id       PK       CCR  HIERARCHY         INCIDENTTIME  \
# 0     54017  2135988   5232936          5  2005-11-24T23:00:00
# 1    274535  3265945  21186829          8  2021-10-11T20:47:00
# 2      3403  2809123  16019890         99  2016-02-02T12:58:00
# 3    191712  3111645  19203614          8  2019-10-06T14:51:00
# 5    239099  3197959  20228065          8  2020-12-11T03:26:00
# ..      ...      ...       ...        ...                  ...
# 548  345493  3409725  23102841          8  2023-07-05T14:44:00
# 549  143343  3022691  18166605          8  2018-08-27T22:23:00
# 550  149761  3034967  18213261         99  2018-10-27T16:43:00
# 551   43711  2110356   5131581         99  2005-07-13T18:45:00
# 552   99904  2113351   5131581         99  2005-07-13T18:45:00
#
#                                     INCIDENTLOCATION CLEAREDFLAG  \
# 0                0 Block TECUMSEH ST PITTSBURGH, PA            N
# 1             1000 Block 5th AV Pittsburgh, PA 15219           N
# ...

# %% [markdown]
# This code prints the number of arson crimes in each neighborhood.

# %%
neighborhood_total = arson_data['INCIDENTNEIGHBORHOOD'].value_counts()
print(neighborhood_total)
# Out:
# Homewood South               19
# Homewood North               17
# Central Business District    14
# Knoxville                    14
# East Hills                   13
#                              ..
# Windgap                       1
# California-Kirkbride          1
# Esplen                        1
# South Oakland                 1
# Arlington                     1
# Name: INCIDENTNEIGHBORHOOD, Length: 76, dtype: int64

# %% [markdown]
# The code groups the data by the "INCIDENT NEIGHBORHOOD" on the x-axis and the y-axis counts how many time arson crimes have orrcued in that neighborhood.

# %%
bar_graph_data = arson_data.groupby("INCIDENTNEIGHBORHOOD").count()
bar_graph_data["OFFENSES"].plot.bar(figsize = (20,20), title=" Neighborhood Arson crimes")

# %% [markdown]
# Then, the code arranges the organized the arsom crimes in from least to most or smallest amount or crimes to most amount of crimes.

# %%
sorted_neighborhoods = bar_graph_data.sort_values("OFFENSES")
sorted_neighborhoods["OFFENSES"].plot.bar(figsize=(20, 20), title="Neighborhood Arson Crimes")

# %% [markdown]
# So, for our project we anaylzed the negihborhoods with the least crime. The best neighborhood would obviously have low crime rates and reports. After analyzing the Arson Metric, I have identifed the negihborhoods with the least amount of arson crimes using data from 2015-2023. The neighborhoods are WindGap, Arlington, and South Oakland with 1 arson crime. My favorite neighborhood is the Strip District. It has lots of shopping stores, activites, and resturants.

# %% [markdown]
# # Introduction

# %% [markdown]
# this project will help to determine whats the best neighborhood in Pittsburgh. We decided to choose data/topics that revolved around crime specifically non-traffic citations because usually the neighborhoods that have very little to no crime tend to be better neightborhoods and have safer enviornments. We also explored other alternatives like quality of living and the best businesses/shops in each neighborhood.

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# the code below prints out the first 100 information from the link

# %%
import pandas as pd
data = pd.read_csv("dataset.csv")
data.head(100)
# Out:
#     _id       PK       CCR GENDER RACE   AGE            CITEDTIME  \
# 0     1  1078081  16157849      M    B  29.0  2016-08-22T23:45:00
# 1     2  1078082  16157849      M    W  21.0  2016-08-22T23:45:00
# 2     3  1078083  16159579    NaN  NaN   NaN  2016-08-25T11:10:00
# 3     4  1078084  16159780      M    B  22.0  2016-08-25T16:42:00
# 4     5  1078085  16161591      F    W  22.0  2016-08-28T00:58:00
# ..  ...      ...       ...    ...  ...   ...                  ...
# 95   96  1077998  16161642      M    W  30.0  2016-08-28T02:25:00
# 96   97  1077999  16162036      M    W  68.0  2016-08-28T19:34:00
# 97   98  1078000  16162768      M    W  56.0  2016-08-29T20:24:00
# 98   99  1078001  16162768      M    W  56.0  2016-08-29T20:24:00
# 99  100  1078002  16162768      M    W  56.0  2016-08-29T20:24:00
#
#                              INCIDENTLOCATION  \
# 0    200 Block N DITHRIDGE ST PITTSBURGH, PA
# 1    200 Block N DITHRIDGE ST PITTSBURGH, PA
# ...

# %% [markdown]
# this code drops all the columns that contain the offences

# %%
data[data['OFFENSES'].notna()]
# Out:
#          _id       PK       CCR GENDER RACE   AGE            CITEDTIME  \
# 0          1  1078081  16157849      M    B  29.0  2016-08-22T23:45:00
# 1          2  1078082  16157849      M    W  21.0  2016-08-22T23:45:00
# 2          3  1078083  16159579    NaN  NaN   NaN  2016-08-25T11:10:00
# 3          4  1078084  16159780      M    B  22.0  2016-08-25T16:42:00
# 4          5  1078085  16161591      F    W  22.0  2016-08-28T00:58:00
# ...      ...      ...       ...    ...  ...   ...                  ...
# 16290  26807  1105891  23179537      F    B  28.0  2023-11-12T00:54:00
# 16291  26808  1105892  23179537      F    B  28.0  2023-11-12T00:54:00
# 16292  26809  1105893  23179983      F    W  23.0  2023-11-12T23:31:00
# 16293  26810  1105894  23180037      F    B  24.0  2023-11-13T02:08:00
# 16294  26811  1105895  23180185      M    B  33.0  2023-11-13T11:33:00
#
#                                     INCIDENTLOCATION  \
# 0           200 Block N DITHRIDGE ST PITTSBURGH, PA
# ...

# %% [markdown]
# This code filters out the data so that only the engage in fihgting citations show

# %%
offense_data = data[data['OFFENSES'].str.contains('ENGAGE IN FIGHTING', case=False, na=False)]
print(offense_data)
# Out:
#          _id       PK       CCR GENDER RACE   AGE            CITEDTIME  \
# 28        29  1078056  16036191      M    W  36.0  2016-03-02T00:30:00
# 34        35  1078322  16169857      F    B  27.0  2016-09-09T21:30:00
# 41        42  1077920  16000875      M    B  28.0  2016-01-02T12:15:00
# 42        43  1077921  16031601      M    B  21.0  2016-02-21T00:30:00
# 56        57  1077851  16153732      F    B  27.0  2016-08-17T04:16:00
# ...      ...      ...       ...    ...  ...   ...                  ...
# 16224  26738  1105782  23171560      M    B  22.0  2023-10-29T17:05:00
# 16235  26749  1105811  23171837      F    B  21.0  2023-10-29T01:10:00
# 16236  26750  1105812  23171845      F    B  23.0  2023-10-29T01:25:00
# 16267  26784  1105854  23176229      F    B  28.0  2023-11-06T02:25:00
# 16275  26792  1105862  23178972      M    W  38.0  2023-11-11T00:27:00
#
#                                INCIDENTLOCATION  \
# 28      E CARSON ST & S 18TH ST PITTSBURGH, PA
# ...

# %%
offense_data_filtered = offense_data[data['NEIGHBORHOOD'].notna()]
print(offense_data_filtered)
# Out:
#          _id       PK       CCR GENDER RACE   AGE            CITEDTIME  \
# 28        29  1078056  16036191      M    W  36.0  2016-03-02T00:30:00
# 34        35  1078322  16169857      F    B  27.0  2016-09-09T21:30:00
# 41        42  1077920  16000875      M    B  28.0  2016-01-02T12:15:00
# 42        43  1077921  16031601      M    B  21.0  2016-02-21T00:30:00
# 56        57  1077851  16153732      F    B  27.0  2016-08-17T04:16:00
# ...      ...      ...       ...    ...  ...   ...                  ...
# 16212  26726  1105770  23170295      F    B  17.0  2023-10-26T14:45:00
# 16224  26738  1105782  23171560      M    B  22.0  2023-10-29T17:05:00
# 16235  26749  1105811  23171837      F    B  21.0  2023-10-29T01:10:00
# 16236  26750  1105812  23171845      F    B  23.0  2023-10-29T01:25:00
# 16267  26784  1105854  23176229      F    B  28.0  2023-11-06T02:25:00
#
#                                INCIDENTLOCATION  \
# 28      E CARSON ST & S 18TH ST PITTSBURGH, PA
# ...

# %% [markdown]
# This code prints the number of engage in fighting in each neighborhood

# %%
neighborhood_counts = offense_data['NEIGHBORHOOD'].value_counts()
print(neighborhood_counts)
# Out:
# South Side Flats             444
# Central Business District    171
# North Shore                   62
# Carrick                       45
# Greenfield                    26
#                             ...
# South Shore                    1
# West End                       1
# Spring Hill-City View          1
# Arlington Heights              1
# Squirrel Hill North            1
# Name: NEIGHBORHOOD, Length: 75, dtype: int64

# %% [markdown]
# This code groups the data by the "NEIGHBORHOOD" column and then count the number of occurances for each neighborhood. After that, it plots a bar chart using the counts.

# %%
import matplotlib.pyplot as plt

realData = offense_data.groupby("NEIGHBORHOOD").count()

realData["OFFENSES"].plot.bar(figsize=(20, 20), title="Engage In Fighting Offenses")
plt.xlabel("Neighborhood")
plt.ylabel("Count of Offenses")
plt.show()  # Show the plot

# %% [markdown]
# The code below arranges the fighting complaints in ascending order

# %%
sortedneighborhood=realData.sort_values("OFFENSES")
sortedneighborhood["OFFENSES"].plot.bar(figsize=(20,20), title="Engage In Fighting Offenses")

# %% [markdown]
# As we can see from the graphs above, South Side Flats has the most highest number of offenses that engage in fighting while the west end has the least amount of offenses.

# %% [markdown]
# # Conclusion

# %% [markdown]
#  personally, my favotite neighborhood is East Liberty. There are a lot of shopping areas like bakery square, target, trader joes, and the farmers market. I wasn't super surprised when I found out that East Liberty doesn't have a lot of offenses like the other neighborhoods since it is a pretty safe area.

# %% [markdown]
# # Best Neightborhood

# %% [markdown]
# According to our anaylsis the neighborhood in Pittsburgh with the least amount of crime also regarded as the safes would be Mount Oliver. Mount Oliver has the least amount of arrest as well as the least amount of engage in fighting offenses. Altough, the neighborhood is not on the arson data set, it is s
